# %% [markdown]
# # 餘弦計算

# %%
reset -f

# %%
import numpy as np
import pandas as pd
import pyodbc

from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr

# %%
# 一般資料
a = [1,2,3,4,5]
b = [3,4,3,6,9]

print('Type = {}, Len = {}'.format(type(a), len(a)))
print('Type = {}, Len = {}'.format(type(b), len(b)))

print(cosine_similarity(a,b))

# 程式無法執行的原因在於：Expected 2D array, got 1D array instead
# a, b 二個各自的元素，因為是存於list資料結構下的第一層，所以有各有5個元素
# 需將各自資料結構內的元素，變成「一組」才能計算…
# Out:
# Type = <class 'list'>, Len = 5
# Type = <class 'list'>, Len = 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ce2daa6782b7> in <module>
#       6 print('Type = {}, Len = {}'.format(type(b), len(b)))
#       7
# ----> 8 print(cosine_similarity(a,b))
#
# C:\Anaconda3\envs\Tfpython\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1176     # to avoid recursive import
#    1177
# -> 1178     X, Y = check_pairwise_arrays(X, Y)
#    1179
#    1180     X_normalized = normalize(X, copy=True)
#
# C:\Anaconda3\envs\Tfpython\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\Anaconda3\envs\Tfpython\lib\site-packages\sklearn\metrics\pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144         X = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#     145                         copy=copy, force_all_finite=force_all_finite,
# --> 146                         estimator=estimator)
#     147         Y = check_array(Y, accept_sparse=accept_sparse, dtype=dtype,
#     148                         copy=copy, force_all_finite=force_all_finite,
#
# C:\Anaconda3\envs\Tfpython\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\Anaconda3\envs\Tfpython\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     622                     "Reshape your data either using array.reshape(-1, 1) if "
#     623                     "your data has a single feature or array.reshape(1, -1) "
# --> 624                     "if it contains a single sample.".format(array))
#     625
#     626         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1. 2. 3. 4. 5.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# 一般資料-修正
a = [1,2,3,4,5]
b = [3,4,3,6,9]

a = [a] # 將 a 的元素，變成一個list，資料下的一組
b = [b] # 將 b 的元素，變成一個list，資料下的一組

print('Type = {}, Len = {}'.format(type(a), len(a)))
print('Type = {}, Len = {}'.format(type(b), len(b)))

print(cosine_similarity(a,b))

# 程式無法執行的原因在於：Expected 2D array, got 1D array instead
# a, b 二個各自的元素，因為是存於list資料結構下的第一層，所以有各有5個元素
# 需將各自資料結構內的元素，變成「一組」才能計算…
# Out:
# Type = <class 'list'>, Len = 1
# Type = <class 'list'>, Len = 1
# [[0.9766078]]

# %%
# 一般資料 & array 差異

a_list = [1, 3, 5]
a_array = np.array([1, 3, 5])

print(a_list, a_array)
print(type(a_list), type(a_array))
# Out:
# [1, 3, 5] [1 3 5]
# <class 'list'> <class 'numpy.ndarray'>

# %% [markdown]
# # 電影資料實測

# %%
conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=(local); DATABASE=MLDATASET;')

# %%
SqlStr = 'SELECT * FROM MOVIE_SUMMARY'

# %%
movie = pd.read_sql(sql=SqlStr, con=conn)

# %%
df = movie.copy()

# %%
df.head()
# Out:
#    userId  ACTION  Adventure  Animation  Children  Comedy  Crime  Documentary  \
# 0   420.0     3.0        2.0        1.0       0.0     7.0    4.0          0.0
# 1   819.0     4.0        2.0        0.0       2.0     9.0    5.0          0.0
# 2   568.0     8.0        5.0        0.0       2.0    21.0   10.0          1.0
# 3   186.0    30.0       13.0        5.0      10.0    13.0   13.0          0.0
# 4   702.0    16.0        9.0        1.0       2.0     6.0    2.0          0.0
#
#    Drama  Fantasy  Film  Horror  Musical  Mystery  Romance   Sci  Thriller  \
# 0   20.0      0.0   2.0     1.0      1.0      7.0      8.0   2.0       9.0
# 1   14.0      0.0   1.0     0.0      1.0      3.0      8.0   1.0       5.0
# 2   41.0      1.0   5.0     2.0      5.0      9.0     17.0   4.0      12.0
# 3   25.0      2.0   3.0     2.0      4.0     10.0      7.0   7.0      51.0
# 4    6.0      0.0   0.0     4.0      3.0      2.0      3.0  11.0       8.0
#
#    War  Western
# 0  3.0      0.0
# 1  3.0      1.0
# 2  8.0      2.0
# 3  2.0      3.0
# 4  4.0      0.0

# %%
UID = 402
c1 = df[df['userId'] == UID].iloc[:,1:]
r1 = df[df['userId'] != UID]

# %%
cosDF = pd.DataFrame()
for i in r1['userId']:
    r2 = r1[r1['userId'] == i].iloc[:,1:]
    cos = pd.DataFrame(zip(r1[r1['userId'] == i]['userId'],cosine_similarity(c1, r2)[0], [pearsonr(c1.values[0], r2.values[0])[0]]))
    cosDF = pd.concat([cosDF, cos])

# %%
cosDF
# Out:
#         0         1         2
# 0   420.0  0.894439  0.819205
# 0   819.0  0.940726  0.891081
# 0   568.0  0.928161  0.868096
# 0   186.0  0.793413  0.606798
# 0   702.0  0.813479  0.620758
# ..    ...       ...       ...
# 0   406.0  0.971058  0.940336
# 0   791.0  0.903990  0.792427
# 0    39.0  0.906789  0.838711
# 0   473.0  0.871545  0.802111
# 0   925.0  0.637800  0.383055
#
# [942 rows x 3 columns]

# %%
# 撰寫為函數

# %%
def UB_CF(data, col, uid):
    
    CP_DF = pd.DataFrame() # 建立餘弦與皮爾森相似資料框
    
    df = data.copy()
    ist = df[col]
    df = df.drop(col, axis = 1)
    df.insert(0, col, ist)          # 將資料的「ID」、「人名」、「主鍵」，唯一識別器放置資料第一順位 
    
    t1 = df[df[col] == uid].iloc[:,1:] # 取出要參照的 ID 資料
    
    # 計算相似性
    for i in df[df[col] != uid][col]:
        t2 = df[df[col] == i].iloc[:,1:]
        t3 = pd.DataFrame(zip(df[df[col] == i][col]
                              , cosine_similarity(t1, t2)[0]                # 餘弦相關
                              , [pearsonr(t1.values[0], t2.values[0])[0]])  # 皮爾森相關
                         , columns=['ID', 'Cos', 'Peas'])       
        CP_DF = pd.concat([CP_DF, t3], axis = 0)
    
    return {'ID_TAG':uid,'Similar_martrix':CP_DF} # 將資料以字典方式存出為二個KEY值；一為參照ID，二為相似資料框架

# %%
UB_CF(data = movie, col = 'userId', uid = 402)
# Out:
# {'ID_TAG': 402,
#  'Similar_martrix':        ID       Cos      Peas
#  0   420.0  0.894439  0.819205
#  0   819.0  0.940726  0.891081
#  0   568.0  0.928161  0.868096
#  0   186.0  0.793413  0.606798
#  0   702.0  0.813479  0.620758
#  ..    ...       ...       ...
#  0   406.0  0.971058  0.940336
#  0   791.0  0.903990  0.792427
#  0    39.0  0.906789  0.838711
#  0   473.0  0.871545  0.802111
#  0   925.0  0.637800  0.383055
#
#  [942 rows x 3 columns]}

# %%
t1 = UB_CF(movie, 'userId', 402)

# %%
t1['ID_TAG']
# Out:
# 402

# %%
t1['Similar_martrix']
# Out:
#        ID       Cos      Peas
# 0   420.0  0.894439  0.819205
# 0   819.0  0.940726  0.891081
# 0   568.0  0.928161  0.868096
# 0   186.0  0.793413  0.606798
# 0   702.0  0.813479  0.620758
# ..    ...       ...       ...
# 0   406.0  0.971058  0.940336
# 0   791.0  0.903990  0.792427
# 0    39.0  0.906789  0.838711
# 0   473.0  0.871545  0.802111
# 0   925.0  0.637800  0.383055
#
# [942 rows x 3 columns]

# %%
t1['Similar_martrix'].sort_values('Peas', ascending=False)
# Out:
#        ID       Cos      Peas
# 0   533.0  0.991529  0.982998
# 0   566.0  0.990872  0.981267
# 0   916.0  0.988799  0.978482
# 0   457.0  0.988582  0.977402
# 0   624.0  0.985695  0.976144
# ..    ...       ...       ...
# 0   604.0  0.579493  0.272680
# 0   822.0  0.629211  0.269629
# 0   366.0  0.467955  0.164612
# 0   814.0  0.483623  0.160718
# 0   471.0  0.428912  0.031464
#
# [942 rows x 3 columns]

# %% [markdown]
# # 相似矩陣測試

# %%
from tqdm import tqdm

# %%
idlist = [i for i in movie['userId'][:8]] # 前8個

# %%
idlist
# Out:
# [420.0, 819.0, 568.0, 186.0, 702.0, 246.0, 836.0, 303.0]

# %%
# 生成相似矩陣
df = pd.DataFrame() # 新建資料框架
for i in tqdm(idlist):
    s1 = UB_CF(data = movie, col= 'userId', uid = i) # 相似矩陣計算
    s2 = s1['Similar_martrix'].sort_values(by = 'Cos',ascending = False)[:5].copy() # 選出前5個最相似ID
    s2['tag'] = s1['ID_TAG']
    df = pd.concat([df, s2], axis = 0)
# Out:
#   0%|                                                                                            | 0/8 [00:00<?, ?it/s]
#
#  12%|██████████▌                                                                         | 1/8 [00:05<00:35,  5.03s/it]
#
#  25%|█████████████████████                                                               | 2/8 [00:10<00:30,  5.13s/it]
#
#  38%|███████████████████████████████▌                                                    | 3/8 [00:15<00:25,  5.11s/it]
#
#  50%|██████████████████████████████████████████                                          | 4/8 [00:20<00:20,  5.12s/it]
#
#  62%|████████████████████████████████████████████████████▌                               | 5/8 [00:25<00:15,  5.14s/it]
#
#  75%|███████████████████████████████████████████████████████████████                     | 6/8 [00:31<00:10,  5.29s/it]
#
#  88%|█████████████████████████████████████████████████████████████████████████▌          | 7/8 [00:36<00:05,  5.36s/it]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:41<00:00,  5.25s/it]

# %%
df.head()
# Out:
#       ID       Cos      Peas    tag
# 0  111.0  0.992023  0.986960  420.0
# 0  284.0  0.987611  0.979515  420.0
# 0  836.0  0.985975  0.977447  420.0
# 0  491.0  0.979387  0.971123  420.0
# 0  713.0  0.978810  0.967277  420.0

# %%
df2 = pd.merge(left=df, right=movie, how='inner', left_on='ID', right_on='userId').iloc[:,0:10].drop('userId', axis = 1).sort_values(by = 'tag',ascending = False)

# %%
df2['ref'] = df2['tag']

# %%
df2.head()
# Out:
#        ID       Cos      Peas    tag  ACTION  Adventure  Animation  Children  \
# 33   47.0  0.984723  0.973897  836.0     1.0        1.0        0.0       1.0
# 34  656.0  0.977122  0.976149  836.0     4.0        0.0        0.0       0.0
# 9   568.0  0.979508  0.963737  836.0     8.0        5.0        0.0       2.0
# 13  556.0  0.983793  0.971270  836.0     5.0        4.0        0.0       2.0
# 32  420.0  0.985975  0.977447  836.0     3.0        2.0        1.0       0.0
#
#     Comedy    ref
# 33     5.0  836.0
# 34     6.0  836.0
# 9     21.0  836.0
# 13    12.0  836.0
# 32     7.0  836.0

# %%
df2.columns
# Out:
# Index(['ID', 'Cos', 'Peas', 'tag', 'ACTION', 'Adventure', 'Animation',
#        'Children', 'Comedy', 'ref'],
#       dtype='object')

# %%
col = ['ref', 'ID', 'Cos', 'Peas', 'ACTION', 'Adventure', 'Animation',
       'Children', 'Comedy']

# %%
df3 = df2[col]

# %%
df3.head()
# Out:
#       ref     ID       Cos      Peas  ACTION  Adventure  Animation  Children  \
# 33  836.0   47.0  0.984723  0.973897     1.0        1.0        0.0       1.0
# 34  836.0  656.0  0.977122  0.976149     4.0        0.0        0.0       0.0
# 9   836.0  568.0  0.979508  0.963737     8.0        5.0        0.0       2.0
# 13  836.0  556.0  0.983793  0.971270     5.0        4.0        0.0       2.0
# 32  836.0  420.0  0.985975  0.977447     3.0        2.0        1.0       0.0
#
#     Comedy
# 33     5.0
# 34     6.0
# 9     21.0
# 13    12.0
# 32     7.0

# %% [markdown]
# # 商品籃OO

# %%
# 物件導向...

class Basket:
    
    def __init__(self, data):
        self.data = data.copy()                        # 避免更動原資料
        self.data.index = range(0, len(self.data))     # 資料索引歸0
        print('Basketbuilding')
        
    def matrixIndex(self, item, method = 'Cos'):       # item：欄位設定；相似度計算預算為餘弦(method)
        self.CPcols = []                               
        cols = item
        for i in cols:                                 # 商品籃與相似度計算
            self.data = pd.concat([self.data, pd.DataFrame(self.data['Cos'] * self.data[i], columns=[method + '_' + i])], axis = 1)
            self.CPcols.append(self.data.columns[-1])
        return self.data
    
    def refoutput(self, flag, uid):                    # 輸出推薦商品排序
        df = pd.DataFrame(self.data[self.data[flag] == uid][self.CPcols].apply(np.sum, axis = 0).sort_values(ascending = False), columns=['Item_Index'])
        df['ID'] = uid
        return df

# %%
# 原始資料檢視
df3.head()
# Out:
#       ref     ID       Cos      Peas  ACTION  Adventure  Animation  Children  \
# 33  836.0   47.0  0.984723  0.973897     1.0        1.0        0.0       1.0
# 34  836.0  656.0  0.977122  0.976149     4.0        0.0        0.0       0.0
# 9   836.0  568.0  0.979508  0.963737     8.0        5.0        0.0       2.0
# 13  836.0  556.0  0.983793  0.971270     5.0        4.0        0.0       2.0
# 32  836.0  420.0  0.985975  0.977447     3.0        2.0        1.0       0.0
#
#     Comedy
# 33     5.0
# 34     6.0
# 9     21.0
# 13    12.0
# 32     7.0

# %%
# 資料輸入
t1 = Basket(df3)
# Out:
# Basketbuilding

# %%
t1.data.head()
# Out:
#      ref     ID       Cos      Peas  ACTION  Adventure  Animation  Children  \
# 0  836.0   47.0  0.984723  0.973897     1.0        1.0        0.0       1.0
# 1  836.0  656.0  0.977122  0.976149     4.0        0.0        0.0       0.0
# 2  836.0  568.0  0.979508  0.963737     8.0        5.0        0.0       2.0
# 3  836.0  556.0  0.983793  0.971270     5.0        4.0        0.0       2.0
# 4  836.0  420.0  0.985975  0.977447     3.0        2.0        1.0       0.0
#
#    Comedy
# 0     5.0
# 1     6.0
# 2    21.0
# 3    12.0
# 4     7.0

# %%
# 相似度指數計算
t1.matrixIndex(item=['ACTION', 'Adventure', 'Animation', 'Children'], method='Cos').head()
# Out:
#      ref     ID       Cos      Peas  ACTION  Adventure  Animation  Children  \
# 0  836.0   47.0  0.984723  0.973897     1.0        1.0        0.0       1.0
# 1  836.0  656.0  0.977122  0.976149     4.0        0.0        0.0       0.0
# 2  836.0  568.0  0.979508  0.963737     8.0        5.0        0.0       2.0
# 3  836.0  556.0  0.983793  0.971270     5.0        4.0        0.0       2.0
# 4  836.0  420.0  0.985975  0.977447     3.0        2.0        1.0       0.0
#
#    Comedy  Cos_ACTION  Cos_Adventure  Cos_Animation  Cos_Children
# 0     5.0    0.984723       0.984723       0.000000      0.984723
# 1     6.0    3.908489       0.000000       0.000000      0.000000
# 2    21.0    7.836066       4.897541       0.000000      1.959017
# 3    12.0    4.918964       3.935171       0.000000      1.967586
# 4     7.0    2.957925       1.971950       0.985975      0.000000

# %%
t1.CPcols
# Out:
# ['Cos_ACTION', 'Cos_Adventure', 'Cos_Animation', 'Cos_Children']

# %%
t1.refoutput(flag='ref', uid=186)
# Out:
#                Item_Index   ID
# Cos_ACTION      99.038499  186
# Cos_Adventure   38.454868  186
# Cos_Children     6.743520  186
# Cos_Animation    3.843730  186

# %%
t1.data[t1.data['ref'] == 186]
# Out:
#       ref     ID       Cos      Peas  ACTION  Adventure  Animation  Children  \
# 35  186.0  164.0  0.956541  0.924335    27.0       12.0        0.0       0.0
# 36  186.0  362.0  0.956898  0.933777    10.0        0.0        0.0       0.0
# 37  186.0  772.0  0.963031  0.934129    12.0        3.0        0.0       2.0
# 38  186.0  396.0  0.973727  0.959713    25.0       10.0        1.0       2.0
# 39  186.0   54.0  0.956668  0.920741    29.0       15.0        3.0       3.0
#
#     Comedy  Cos_ACTION  Cos_Adventure  Cos_Animation  Cos_Children
# 35     7.0   25.826601      11.478489       0.000000      0.000000
# 36     5.0    9.568985       0.000000       0.000000      0.000000
# 37     5.0   11.556377       2.889094       0.000000      1.926063
# 38     6.0   24.343171       9.737268       0.973727      1.947454
# 39    11.0   27.743365      14.350016       2.870003      2.870003
